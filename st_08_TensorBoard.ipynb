# %% [markdown]
# # TensorBoard : Web based Monitoring

# %% [markdown]
# ### Monitoring Cifar-10

# %%
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.datasets import cifar10
import os

# %% [markdown]
# Loading CIFAR-10 dataset

# %%
((trainX, trainY), (testX, testY)) = cifar10.load_data()
trainX = trainX.astype("float") / 255.0
testX = testX.astype("float") / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
trainY = to_categorical(trainY)
testY = to_categorical(testY)

# %%
labelNames = ["airplane", "automobile", "bird", "cat", "deer",
              "dog", "frog", "horse", "ship", "truck"]

# %% [markdown]
# Define CNN Model

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Dense

class MiniVGGNet:
    @staticmethod
    def build(width, height, depth, classes):
        # initialize the model along with the input shape to be
        # "channels last" and the channels dimension itself
        model = Sequential()
        inputShape = (height, width, depth)
        chanDim = -1

        # first CONV => RELU => CONV => RELU => POOL layer set
        model.add(Conv2D(32, (3, 3), padding="same",
            input_shape=inputShape))
        model.add(Activation("relu"))
        model.add(Conv2D(32, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # second CONV => RELU => CONV => RELU => POOL layer set
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(Conv2D(64, (3, 3), padding="same"))
        model.add(Activation("relu"))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # first (and only) set of FC => RELU layers
        model.add(Flatten())
        model.add(Dense(512))
        model.add(Activation("relu"))
        model.add(Dropout(0.5))

        # softmax classifier
        model.add(Dense(classes))
        model.add(Activation("softmax"))

        # return the constructed network architecture
        return model

# %% [markdown]
# Compiling model

# %%
opt = SGD(lr=0.01, momentum=0.9, nesterov=True)
model = MiniVGGNet.build(width=32, height=32, depth=3, classes=10)
model.compile(loss="categorical_crossentropy", optimizer=opt,
              metrics=["accuracy"])

# %% [markdown]
# Setup tensorboard

# %%
# %load_ext tensorboard

# %%
mkdir logs

# %%
# insert code
callbacks = [tf.keras.callbacks.TensorBoard(log_dir = './logs', histogram_freq = 0)]

# %%
# %tensorboard --logdir='./logs'

# %% [markdown]
# Training network...

# %%
model.fit(trainX, trainY, validation_data=(testX, testY),
                batch_size=256, epochs=100, callbacks=callbacks, verbose=1)
# Out:
# Epoch 1/100
#   1/196 [..............................] - ETA: 0s - loss: 2.3290 - accuracy: 0.0938WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/196 [..............................] - ETA: 6s - loss: 2.3235 - accuracy: 0.1016WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0140s vs `on_train_batch_end` time: 0.0504s). Check your callbacks.
# 196/196 [==============================] - 4s 23ms/step - loss: 2.0840 - accuracy: 0.2264 - val_loss: 1.8812 - val_accuracy: 0.3325
# Epoch 2/100
# 196/196 [==============================] - 4s 21ms/step - loss: 1.7214 - accuracy: 0.3796 - val_loss: 1.5433 - val_accuracy: 0.4410
# Epoch 3/100
# 196/196 [==============================] - 4s 21ms/step - loss: 1.4909 - accuracy: 0.4613 - val_loss: 1.4006 - val_accuracy: 0.4964
# Epoch 4/100
# 196/196 [==============================] - 4s 21ms/step - loss: 1.3656 - accuracy: 0.5073 - val_loss: 1.2483 - val_accuracy: 0.5524
# Epoch 5/100
# 196/196 [==============================] - 4s 21ms/step - loss: 1.2716 - accuracy: 0.5439 - val_loss: 1.1671 - val_accuracy: 0.5808
# Epoch 6/100
# 196/196 [==============================] - 4s 21ms/step - loss: 1.1931 - accuracy: 0.5724 - val_loss: 1.1275 - val_accuracy: 0.6046
# Epoch 7/100
# 196/196 [==============================] - 4s 21ms/step - loss: 1.
100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1875 - accuracy: 0.9326 - val_loss: 0.7032 - val_accuracy: 0.7991
# Epoch 62/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1841 - accuracy: 0.9345 - val_loss: 0.7073 - val_accuracy: 0.8015
# Epoch 63/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1846 - accuracy: 0.9340 - val_loss: 0.7194 - val_accuracy: 0.7999
# Epoch 64/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1815 - accuracy: 0.9354 - val_loss: 0.6810 - val_accuracy: 0.8042
# Epoch 65/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1763 - accuracy: 0.9372 - val_loss: 0.7033 - val_accuracy: 0.7986
# Epoch 66/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1711 - accuracy: 0.9390 - val_loss: 0.7366 - val_accuracy: 0.7998
# Epoch 67/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1696 - accuracy: 0.9384 - val_loss: 0.7177 - val_accuracy: 0.8029
# Epoch 68/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1690 - accuracy: 0.9397 - val_loss: 0.7257 - val_accuracy: 0.8000
# Epoch 69/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1611 - accuracy: 0.9423 - val_loss: 0.7375 - val_accuracy: 0.8021
# Epoch 70/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1591 - accuracy: 0.9428 - val_loss: 0.7350 - val_accuracy: 0.8052
# Epoch 71/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1591 - accuracy: 0.9434 - val_loss: 0.7433 - val_accuracy: 0.8028
# Epoch 72/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1605 - accuracy: 0.9423 - val_loss: 0.7415 - val_accuracy: 0.8005
# Epoch 73/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1571 - accuracy: 0.9437 - val_loss: 0.7384 - val_accuracy: 0.8025
# Epoch 74/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1502 - accuracy: 0.9463 - val_loss: 0.7425 - val_accuracy: 0.8082
# Epoch 75/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1466 - accuracy: 0.9473 - val_loss: 0.7642 - val_accuracy: 0.7998
# Epoch 76/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1491 - accuracy: 0.9468 - val_loss: 0.7385 - val_accuracy: 0.8043
# Epoch 77/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1440 - accuracy: 0.9492 - val_loss: 0.7619 - val_accuracy: 0.7997
# Epoch 78/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1420 - accuracy: 0.9491 - val_loss: 0.7734 - val_accuracy: 0.8010
# Epoch 79/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1416 - accuracy: 0.9484 - val_loss: 0.7354 - val_accuracy: 0.8021
# Epoch 80/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1392 - accuracy: 0.9497 - val_loss: 0.7460 - val_accuracy: 0.8038
# Epoch 81/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1370 - accuracy: 0.9522 - val_loss: 0.7560 - val_accuracy: 0.8049
# Epoch 82/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1403 - accuracy: 0.9507 - val_loss: 0.7521 - val_accuracy: 0.8080
# Epoch 83/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1310 - accuracy: 0.9535 - val_loss: 0.7768 - val_accuracy: 0.8041
# Epoch 84/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1321 - accuracy: 0.9542 - val_loss: 0.7641 - val_accuracy: 0.8082
# Epoch 85/100
# 196/196 [==============================] - 4s 20ms/step - loss: 0.1313 - accuracy: 0.9540 - val_loss: 0.7515 - val_accuracy: 0.8074
# Epoch 86/100
# 196/196 [==============================] - 4s 21ms/step - loss: 0.1256 - accuracy: 0.9555 - val_loss: 0.7652 - val_accuracy: 0.8061
# Epoch 87/100
#  49/196 [======>.......................] - ETA: 2s - loss: 0.1309 - accuracy: 0.9542
